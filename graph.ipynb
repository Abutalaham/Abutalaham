# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('autompg.csv')
print(df)
# Out:
#    mpg  cylinder  origin carname
# 0   18         8       1  suzuki
# 1   15         8       1  bulero
# 2   18         6       1   lambo
# 3   16         4       1    ford
# 4   17         8       1     BMW

# %%
df.plot.bar(x='carname',y='mpg')
# Out:
# <Axes: xlabel='carname'>

# %%
df.plot.line(x='mpg',y='cylinder')
# Out:
# <Axes: xlabel='mpg'>

# %%
df.plot.pie(x='mpg',y='cylinder')
# Out:
# <Axes: ylabel='cylinder'>

# %%
sns.scatterplot(data=df,x='carname',y='mpg')
# Out:
# <Axes: xlabel='carname', ylabel='mpg'>
