# %%
import numpy as np
import pandas as pd
df = pd.read_csv('cricket(xl).csv')
print(df)
# Out:
#   competition  matches  runs
# 0        TEST      132  2506
# 1         ODI      271   935
# 2          FC      344  5572
# 3          LA      380  1456
# 4        TEST      240  2506
# 5         ODI      271  3506

# %%
#aggrecate function
df['runs'].mean()
df['runs'].max()
df['runs'].median()
# Out:
# 2506.0
